# %%
import pandas as pd

# %%
salary_df = pd.read_csv('Resources/Levels_Fyi_Salary_Data.csv')
salary_df.head()
# Out:
#           timestamp company     level              title  \
# 0    8/12/2020 0:22  Abbott  Grade 19  Hardware Engineer
# 1    12/9/2020 0:12  Abbott  Grade 19  Hardware Engineer
# 2   6/11/2017 14:53  Amazon        L7    Product Manager
# 3    2/10/2021 1:18  Abbott        19  Software Engineer
# 4  11/29/2017 10:36    Sony        L2  Software Engineer
#
#    totalyearlycompensation     location Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                   200000      Alameda         CA         NaN         NaN
# 1                   198000      Alameda         CA         NaN         NaN
# 2                   310000      Seattle         WA         NaN         NaN
# 3                   300000      Alameda         CA         NaN         NaN
# 4                   125000  Aliso Viejo         CA         NaN         NaN
#
#    basesalary  ...  Doctorate_Degree  Highschool Some_College Race_Asian  \
# 0      168000  ...                 0           0            0          1
# ...

# %%
salary_df.dtypes
# Out:
# timestamp                   object
# company                     object
# level                       object
# title                       object
# totalyearlycompensation      int64
# location                    object
# Unnamed: 6                  object
# Unnamed: 7                 float64
# Unnamed: 8                 float64
# basesalary                   int64
# stockgrantvalue            float64
# bonus                      float64
# gender                      object
# otherdetails                object
# cityid                       int64
# dmaid                      float64
# rowNumber                    int64
# Masters_Degree               int64
# Bachelors_Degree             int64
# Doctorate_Degree             int64
# Highschool                   int64
# Some_College                 int64
# Race_Asian                   int64
# Race_White                   int64
# Race_Two_Or_More             int64
# Race_Black                   int64
# Race_Hispanic                int64
# ...

# %%
salary_df = salary_df.rename(columns={"Unnamed: 6" : "State"})

# %%
salary_df.drop(["Unnamed: 7", "Unnamed: 8", ""], axis=1)
# Out:
#               timestamp           company     level              title  \
# 0        8/12/2020 0:22            Abbott  Grade 19  Hardware Engineer
# 1        12/9/2020 0:12            Abbott  Grade 19  Hardware Engineer
# 2       6/11/2017 14:53            Amazon        L7    Product Manager
# 3        2/10/2021 1:18            Abbott        19  Software Engineer
# 4      11/29/2017 10:36              Sony        L2  Software Engineer
# ...                 ...               ...       ...                ...
# 52835    9/6/2018 21:24            amazon      sde2  Software Engineer
# 52836    9/9/2018 11:52            Google        T4  Software Engineer
# 52837    9/13/2018 8:23         Microsoft        62  Software Engineer
# 52838   9/13/2018 14:35              MSFT        63  Software Engineer
# 52839   9/14/2020 15:31  Northrop Grumman        L1  Software Engineer
#
#        totalyearlycompensation        location State  basesalary  \
# ...

# %%
salary_df.dtypes
# Out:
# timestamp                   object
# company                     object
# level                       object
# title                       object
# totalyearlycompensation      int64
# location                    object
# State                       object
# Unnamed: 7                 float64
# Unnamed: 8                 float64
# basesalary                   int64
# stockgrantvalue            float64
# bonus                      float64
# gender                      object
# otherdetails                object
# cityid                       int64
# dmaid                      float64
# rowNumber                    int64
# Masters_Degree               int64
# Bachelors_Degree             int64
# Doctorate_Degree             int64
# Highschool                   int64
# Some_College                 int64
# Race_Asian                   int64
# Race_White                   int64
# Race_Two_Or_More             int64
# Race_Black                   int64
# Race_Hispanic                int64
# ...
